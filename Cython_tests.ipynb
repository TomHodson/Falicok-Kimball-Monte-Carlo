# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wrapped_C_functions import diagonalise_scipy
import numpy as np

# %%
from quantum_montecarlo import quantum_cython_mcmc
import h5py

config = dict(N_steps = 10**2,
              N_system = 128,
              mu = 0,
              beta = 0.1,
              V=-1,
              alpha=1.5,
              U = 1,
              return_names = True,
              #this is necessary for hd5 to know how to save it
            )

# %time quantum_cython_mcmc(**config)
# Out:
# CPU times: user 6min 35s, sys: 29.3 s, total: 7min 5s
# Wall time: 36.4 s
# (('classical_energies', 'quantum_energies', 'numbers', 'magnetisations'),
#  (array([-128.        , -117.67454974,  -93.04406055,  -77.81728035,
#           -56.5625955 ,  -54.91498706,  -50.60879976,  -41.51283862,
#           -36.89856017,  -34.88524126,  -32.34376824,  -26.19868405,
#           -14.18612669,  -10.99646786,   -4.20692749,   -3.16970682,
#            -1.01302787,   -3.59398091,   -2.60408691,   -4.32085573,
#            -4.04465467,   -4.7929726 ,   -7.57467344,   -5.88099249,
#            -6.18409283,   -6.03913585,   -7.64271599,   -5.51041181,
#            -4.65919048,   -1.88898644,   -3.57877229,   -3.16481063,
#            -3.52281   ,   -5.35391223,   -4.94605588,   -7.71443065,
#           -11.02622253,  -10.31731034,   -9.93956679,   -5.37253047,
#            -3.74291279,   -2.02537248,   -2.93643059,   -4.93025615,
# ...

# %%
# %load_ext cython
